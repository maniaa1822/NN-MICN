# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data_pred = np.load('results/long_term_forecast_weather_96_192_MICN_custom_ftMS_sl96_ll96_pl192_dm32_nh8_el2_dl1_df32_fc3_ebtimeF_dtTrue_test_0/pred.npy')

data_true = np.load('results/long_term_forecast_weather_96_192_MICN_custom_ftMS_sl96_ll96_pl192_dm32_nh8_el2_dl1_df32_fc3_ebtimeF_dtTrue_test_0/true.npy')

# %%
plt.plot(data_pred[0, :, 0], label='pred')
plt.plot(data_true[0, :, 0], label='true')
